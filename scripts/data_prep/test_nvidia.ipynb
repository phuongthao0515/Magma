# %%
# !nvidia-smi
# Out:
# Failed to start the Kernel 'Python 3 (ipykernel)'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details. Unable to get resolved server information for google.colab:colab:b4ee1319-ab5f-40ae-a247-080515eac110
