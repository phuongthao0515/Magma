# %%
# !git clone https://github.com/phuongthao0515/Magma.git
# %cd Magma
# !git checkout feat/qlora-office-config
# Out:
# Cloning into 'Magma'...
# remote: Enumerating objects: 697, done.
# remote: Counting objects: 100% (218/218), done.
# remote: Compressing objects: 100% (126/126), done.
# remote: Total 697 (delta 114), reused 109 (delta 91), pack-reused 479 (from 2)
# Receiving objects: 100% (697/697), 40.72 MiB | 9.93 MiB/s, done.
# Resolving deltas: 100% (296/296), done.
# /content/Magma
# Branch 'feat/qlora-office-config' set up to track remote branch 'feat/qlora-office-config' from 'origin'.
# Switched to a new branch 'feat/qlora-office-config'

# %%
# !git config user.email "lpthao150504@gmail.com"
# !git config user.name "Thao Le"
# !git add .
# !git commit -m "Updates from Colab"
# !git push origin feat/qlora-office-config
# Out:
# On branch feat/qlora-office-config
# Your branch is up to date with 'origin/feat/qlora-office-config'.
#
# nothing to commit, working tree clean
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !python scripts/data_prep/convert_mind2web.py --val_ratio 0.2
# Out:
# usage: convert_mind2web.py [-h] [--dataset_name DATASET_NAME] [--split SPLIT]
#                            [--output_dir OUTPUT_DIR]
#                            [--max_samples MAX_SAMPLES] [--skip_download]
# convert_mind2web.py: error: unrecognized arguments: --val_ratio 0.2
